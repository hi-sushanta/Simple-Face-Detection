# %% [markdown]
# # Simple face detection

# %%
# !pip install opencv-python
# !apt-get update
# !apt-get install ffmpeg libsm6 libxext6  -y
# !wget https://s3.amazonaws.com/ps.public.resources/ml-showcase/fcb.jpg
# !wget https://s3.amazonaws.com/ps.public.resources/ml-showcase/messi.jpg
# Out:
# Requirement already satisfied: opencv-python in /root/venv/lib/python3.7/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from opencv-python) (1.21.5)
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://deb.debian.org/debian buster-updates InRelease
# Hit:3 http://security.debian.org/debian-security buster/updates InRelease
#
#
#
#
# libsm6 is already the newest version (2:1.2.3-1).
# libxext6 is already the newest version (2:1.3.3-1+b2).
# ffmpeg is already the newest version (7:4.1.8-0+deb10u1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# --2022-03-13 05:59:33--  https://s3.amazonaws.com/ps.public.resources/ml-showcase/fcb.jpg
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.137.6
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.137.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99779 (97K) [image/jpeg]
# Saving to: ‘fcb.jpg.1’
#
# fcb.jpg.1           100%[===================>]  97.44K  --.-KB/s    in 0.003s
#
# 2022-03-13 05:59:34 (28.7 MB/s) - ‘fcb.jpg.1’ saved [99779/99779]
#
# --2022-03-13 05:59:34--  https://s3.amazonaws.com/ps.public.resources/ml-showcase/messi.jpg
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.49.19
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.49.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 325059 (317K) [image/jpeg]
# Saving to: ‘messi.jpg.1’
#
# messi.jpg.1         100%[===================>] 317.44K  --.-KB/s    in 0.003s
#
# 2022-03-13 05:59:34 (89.9 MB/s) - ‘messi.jpg.1’ saved [325059/325059]

# %%
import cv2
import sys
import matplotlib.pyplot as plt
from cv2 import CascadeClassifier
from cv2 import rectangle

# %%
# Load your image; here we'll test it out with Barcelona's football team
im1 = cv2.imread('fcb.jpg')
im2 = cv2.imread('messi.jpg')

# %%
# Load the pre-trained model
classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# Perform face detection
def detect_faces(im):
    bboxes = classifier.detectMultiScale(im)

    # Print bounding box for each detected face
    for box in bboxes:
        # Extract
        x, y, width, height = box
        x2, y2 = x + width, y + height
        # Draw a rectangle over the pixels
        rectangle(im, (x, y), (x2, y2), (0, 0, 255), 1)
        
    plt.figure(figsize = (12,10))
    plt.axis('off')
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
detect_faces(im1)

# %%
detect_faces(im2)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9cc8d813-6f1a-4174-b3e8-966d835d6140' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
